# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("watch_history.csv")

# %%
data.head(10)
# Out:
#   watch_id  user_id  movie_id  watch_date  watch_duration device_type
# 0   W20000    15013      2027  2024-11-01           115.0      Laptop
# 1   W20001    15008      2393  2024-11-01           135.0      Mobile
# 2   W20002    15015       437  2024-11-01           106.0      Laptop
# 3   W20003    15006       279  2024-11-01             9.0    Smart TV
# 4   W20004    15004      1137  2024-11-01            99.0      Mobile
# 5   W20005    15003      1823  2024-11-01           126.0    Smart TV
# 6   W20006    15017      2362  2024-11-01           150.0      Laptop
# 7   W20007    15018      2027  2024-11-01             6.0      Mobile
# 8   W20008    15017      1208  2024-11-01           103.0      Laptop
# 9   W20009    15008       913  2024-11-01            78.0    Smart TV

# %%
data.shape
# Out:
# (98923, 6)

# %%
sns.lineplot(x='device_type', y='watch_duration', data=data)
plt.title("Average Watch Duration by Device Type")
plt.show()

# %%
data['device_type'].value_counts()
# Out:
# device_type
# Laptop             42235
# Smart TV           33495
# Mobile             22394
# Washing Machine      210
# Shoe Box             200
# Toaster              192
# Name: count, dtype: int64

# %%
import pandas as pd

# List of unwanted device types
unwanted_devices = ['Toaster', 'Shoe Box', 'Washing Machine']

# Replace them with 'Other'
data['device_type'] = data['device_type'].replace(unwanted_devices, 'Other')

# Replace NaN values with 'Other'
data['device_type'] = data['device_type'].fillna('Other')

# %%
plt.figure(figsize=(10, 5))
sns.barplot(x='device_type', y='watch_duration', data=data)
plt.title("Average Watch Duration by Device Type (Cleaned)")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
data['watch_duration'].value_counts()
# Out:
# watch_duration
# 99.0     1610
# 105.0    1572
# 97.0     1557
# 98.0     1523
# 103.0    1473
#          ...
# 227.0       1
# 219.0       1
# 241.0       1
# 226.0       1
# 209.0       1
# Name: count, Length: 239, dtype: int64

# %%
data.drop_duplicates(inplace=True)

# %%
data.to_csv("watch_history_modified.csv",index=False)
